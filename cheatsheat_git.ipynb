# %% [markdown]
# # Github Cheatsheet

# %% [markdown]
# <a id="Index"><a>

# %% [markdown]
# # Index

# %% [markdown]
# [GitHub Tutorial](https://try.github.io/levels/1/challenges/1)

# %% [markdown]
# Browse to a folder and create a git repository:
# ```
# $ git init
# ```
#
# Add Files to the repository (already in the folder) or add all the folder (-A) or add all that match (*)
#
# ```
# $ git add file.txt
# $ git add -A
# $ git add '*.txt'
#
# ```
#
# Stage the removal of file (After the file removal rm file)
# ```
# git rm <file_name>
# ```
#
# Check Status/changes of the repository
#
# ```
# $ git status
# ```
#
# Commit a change of a file to the repository
#
# ```
# $ git commit -m "A name for the change I have made"
# ```
#
# Remove a file or files from the staging area.
# ```
# $ git reset filename
# ```
#
# Browse all the commits
# ```
# $ git log
# ```
# Push/Upload a repository to github (it must end with .git)
#
# ```
# $ git remote add origin https://github.com/rcontesti/notebooks.git
# $ git push -u origin master
# ```
# Change/remove github repository origin
#
# ```
# $ git remote rm origin
# ```
#
# Download/Push files from a repository
#
# ```
# $git pull origin master
# ```
#
# See differences between remote and local repository
# ```
# $ git diff HEAD
# ```
# Undo: get rid of all the changes since the last commit
# ```
# $  git checkout -- filename.txt
# ```
# Create a branch
#
# ```
# $  git branch branchname
# ```
# See Branches
#
# ```
# $  git branch
# ```
#
# Move to another branch (Yes the same as creating a branch)
#
# ```
# $  git branch branchname
# ```
#
# Remove files (It also stages the removal)
# ```
# $ git rm '*.txt'
# ```
#
# Merge a branch to the master
# ```
# $ git merge branchname
# ```
#
# Delete the branch that has been merged
# ```
# $ git branch -d branchname
# ```

# %% [markdown]
# By topic (ME)
# =======
#
# # 1 create folder
# ```
# mkdir
# ```
# (#1 Add remote and pull folder)
# # 2 Inititialize git
# git init
# git status
# # 3 Create files in jupyter
#
# # 4 Add the file to the staging area (not yet in repository)
# git add *.ipynb
# # 5 Commit staged file
# git commit -m "File creation"
#
#
# # PUSHING AND PULLING
#
# ## Add to github repository origin
# ## (**THE ORIGIN REPOSITORY CANNOT BE CREATED FROM COMMAND LINE**)
#
# git remote add origin https://github.com/try-git/try_git.git
#
# ## Push the changes we have m
#  #origin=github repository
#  #master=branch we are pushing
#  #-u= remember parameters so next time we can only type git push
# git push -u origin master
# #Pull from github repository the master branch
# git push -u origin master
#
#
#
# ## MOVING FILES AND VERSION
# #Check Mistakes
# git log
#
# #Check Differences between the last commit in our local git (HEAD) to the one online
# git diff HEAD
#
# #Unstage files
# git reset octofamily/octodog.txt
#
# # Remove all the changes to file since the last commit
# git checkout -- octocat.txt
#
# ##BRANCH
# #Create a Branch
# git branch <branch_name>
# #check branches
# git branch
# #Switch to a different branch
# git checkout <branch_name>
# #Merge, once you in the master branch (use checkout), merge the other branch
# git merge <branch_name>
# #Delete a branch
# git branch -d <branch_name>
#
# # FILES AND FOLDERS
# #Remove files
# git rm <file_name>
